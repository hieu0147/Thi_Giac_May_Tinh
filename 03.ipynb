# %%
from imgtools import *

# %%
dir = 'C:/Users/admin/Desktop/nhung_mon_hoc/thi_giac_may_tinh/anh'
image_path = dir + '/image.jpg'
print(image_path)
# Out:
# C:/Users/admin/Desktop/nhung_mon_hoc/thi_giac_may_tinh/anh/image.jpg

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1536x1902>

# %%
print(img.size)
# Out:
# (1536, 1902)

# %%
new_size = (100,100)
new_image = img.resize(new_size)
display(new_image)
# task: luu anh moi ve may
path1 = dir + '/02.PNG'
new_image.save(path1)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
# thay doi kich thuoc
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# task: luu anh moi ve may
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=40x50>

# %%
path2 = dir + '/01.JPG'
img.save(path2)
