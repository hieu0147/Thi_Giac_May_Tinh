# %%
from PIL import Image

# %%
dir = 'C:/Users/admin/Desktop/nhung_mon_hoc/thi_giac_may_tinh/anh'

# %%
image_path = dir + '/image.jpg'
print(image_path)
# Out:
# C:/Users/admin/Desktop/nhung_mon_hoc/thi_giac_may_tinh/anh/image.jpg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1536x1902>

# %%
print("Định dạng ảnh: ", img01.format)
# Out:
# Định dạng ảnh:  JPEG

# %%
print("Kích thước ảnh: ", img01.size)
# Out:
# Kích thước ảnh:  (1536, 1902)

# %%
new_img_01_path = dir + '/new_01.JPG'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
img01.close()
