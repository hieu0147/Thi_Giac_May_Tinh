# %%
from imgtools import *

# %%
dir = 'C:/Users/admin/Desktop/nhung_mon_hoc/thi_giac_may_tinh/anh'
image_path = dir + '/anh.png'

# %%
img = load_image(image_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=528x781>

# %%
# dinh vi khu vuc cat
region = (100, 75, 175, 150)
# cat vung anh
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=75x75>

# %%
# dan
# xác dinh vi tri can dan
paste_position = (250, 250)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=528x781>
