# %%
from imgtools import *
from PIL import Image

# %%
dir = 'C:/Users/admin/Desktop/nhung_mon_hoc/thi_giac_may_tinh/anh'
image_path = dir + '/anh.png'

# %%
img = load_image(image_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=528x781>

# %%
# xoay anh
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=528x781>

# %%
# transpose anh
transposed_image = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=781x528>
